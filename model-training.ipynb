# %%
# Taking the fall dataset from the roboflow

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PZQCJj4dXlWwCyztfDqO")
project = rf.workspace("win-lan-pfbyz").project("fall-detection-active-learning")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 736.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 6.0 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
import os
# Set WANDB_MODE environment variable to dryrun
os.environ['WANDB_MODE'] = 'dryrun'

# %%
with open('custom.yaml', 'w') as f:
    f.write('''
names:
- Fall Detected
- Sitting
- Walking
nc: 3
test: ../test/images
train: /kaggle/working/fall-detection-active-learning-4/train/images
val: /kaggle/working/fall-detection-active-learning-4/valid/images
''')
print('completed')
# Out:
# completed

# %%
# !yolo task=detect mode=train model='yolov8n.pt' data=custom.yaml epochs=300 imgsz=640 plots=True name=fall_detect device=0,1
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                      CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
# Resume an interrupted training
# yolo train resume model=/kaggle/working/runs/detect/fall_detect6/weights/last.pt device=0,1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PZQCJj4dXlWwCyztfDqO")
project = rf.workspace("ltttnt").project("fire-vqbia")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.2, to fix: `pip install ultralytics==8.0.196`

# %%
with open('custom1.yaml', 'w') as f:
    f.write('''
names:
- Fire
nc: 1
test: ../test/images
train: /kaggle/working/FIRE-1/train/images
val: /kaggle/working/FIRE-1/valid/images
''')
print('completed')
# Out:
# completed

# %%
# !yolo task=detect mode=train model='yolov8n.pt' data=custom1.yaml epochs=300 imgsz=640 plots=True name=fire_detect device=0,1
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                      CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
# Create a new file named "example.txt" and write some content to it
with open('custom2.yaml', 'w') as f:
    f.write('''
# YOLOv8 🚀 by Ultralytics, AGPL-3.0 license
# COCO128 dataset https://www.kaggle.com/ultralytics/coco128 (first 128 images from COCO train2017) by Ultralytics
# Example usage: python train.py --data coco128.yaml
# parent
# ├── yolov8
# └── datasets
#     └── coco128  ← downloads here (7 MB)

# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
# path: ../datasets/coco128 # dataset root dir
train: /kaggle/input/sagar-rohan-face-data/train_data/images/train # train images (relative to 'path') 128 images
val: /kaggle/input/sagar-rohan-face-data/train_data/images/val # val images (relative to 'path') 128 images
test: # test images (optional)

# Classes

names:
  0: fire
  1: stranger
  2: rohan
  3: sagar
''')
print('completed')

# %%
# !yolo task=detect mode=train model='yolov8n.pt' data=custom2.yaml epochs=100 imgsz=640 plots=True name=sagar_rohan device=0,1
